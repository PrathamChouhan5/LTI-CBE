# %% [raw]
# # General purpose programming language
# Comprehensive, Interpreter, OOPS
# Modules & packages
# Data Science --> Numpy, Pandas, scipy, sklearn, keras, Pytorch
# IOT --> Raspberry pie, Ordinov, Sockets
# Testing --> Junit, selenium
# Parallel processing --> Multi threading, Pyspark
# Big data --> pydoop, hadoopy, mr-job
# web application --> Flask, Django

# %%
v2 = 100

# %%
v1 = 10

# %%
v2==v1

# %%
v2>v1

# %%
v2!=v1

# %%
11%2

# %%
11//2

# %%
2**3

# %% [markdown]
# ### Data Structures

# %%
# Ordered Data Structures --> Strings, Lists, Tuples

# %%
s = "hello, welcome to the class"

# %%
s

# %%
s[26]

# %%
type(s)

# %%
len(s)

# %%
s[:5]

# %%
s[::]

# %%
s[::2]

# %%
s[7:]

# %%
s[:-1]

# %%
s[7:15]

# %%
dir(s)

# %%
s.capitalize()

# %%
s[7:].capitalize()

# %%
help(s.islower)

# %%
s.replace('a','E')

# %%
"hi"+"hi"

# %%
'hi'*2

# %%
o = 'i love oringes'

# %%
# Immutable
o[2] = 'a'

# %%
o[:3]+o[3:].replace('i','a')

# %%
o[:9]+'a'+o[10:]

# %%
s.split(' ')

# %%
l = [1,10,88,'hello','apples','oranges']

# %%
l[4].capitalize()

# %%
l[2] = 8888

# %%
l[3] = 'hi'

# %%
l[3][0] = p

# %%
l.pop()

# %%
l.append('berries')

# %%
l.append(['cbe','del'])

# %%
l.extend('mum')

# %%
s.__add__('vbyvdv')

# %%
l.__add__([2])

# %%
dir(l)

# %%
[]

# %%
1,'a'

# %%
t = (1,'a',100)

# %%
t[1]='hello'

# %%
# Un-ordered data structures --> Dictionaries and sets

# %%
d = dict()

# %%
d['ID'] = [1,2,3]

# %%
d['Name'] = ['John','Sean','Monika']

# %%
d['Salary'] = (100,200,300,400)

# %%
d.popitem()

# %%
d['Salary'] = (100,200,300)

# %%
d = {'eid':[1,2,3],'ecity':['mum','del','cbe']}

# %%
d.keys()

# %%
d.values()

# %%
d.items()

# %%
del(d['ecity'][0])

# %%
d

# %%
d['Name'].remove('Sean')

# %%
d['eid'][2]

# %%
# Sets

# %%
s1 = set()

# %%
type(s1)

# %%
s1 = {'a','b','d','c','a','A',1,2,3,3,3,3,3,3}

# %%
s1

# %%
s2 = {'a','b',2,3,100}

# %%
s2|s1

# %%
s1&s2

# %%
int(10.689562965)

# %%
list(set(['mum','mum','che','cbe']))

# %%
s2.issubset(s1)

# %%
s2.difference_update(s1)

# %%
s2

# %%
input()

# %%
bal = 28000
amt = int(input("enter an amount to be withdrawn"))
print("The amount withdrawn is {} and the balance is {}".format(amt, (bal-amt)))

# %%
stocks = 10
ordered = 15
print("current stocks is {1} and and we need {0} more to be delivered".format(ordered, stocks))

# %%
# fstring
# %d (int), %s (string)

# %%
# Conditions

# %%
sal = 7000

# %%
if sal<10000:
    print("average")

# %%
if sal<10000:
    print("average")
else:
    print("good")

# %%
if (sal>10000)&(sal<20000):
    print("good")
elif (sal>20000):
    print("excellent")
else:
    print("avg")

# %%
sal=int(input("enter your salary"))
if (sal>0):
    print("positive")
    if (sal>=10000):
        print("even better")
else:
    print('please input a positive number')
print("goodbye")

# %% [raw]
# Ask the user for a input", If the input is greater than zero, print positive,
# also print whether it is multiples of 5,2
# if not multiple of 5 or 2, print(neither divisible by 5 or 2) else negative

# %%
'i' in 'python'

# %%
# iterations

# %%
for num in range(5):
    #print(i+1)
    print(num)

# %%
for i in "hello":
    print(i.upper(), end='---')

# %%
for i,j in d.items():
    print(i,":",j[1])

# %%
# Banana --> find out the number of instances where letter a has occured and return the positions of it

# %%
c = 0
l = 0
s1 = "banana"

# %%
# Keywords in conditions & Iterations
# Break, Continue & pass

# %%
num = 0
for i in range(10):
    #print(num,end=" ")
    #num = num+1
    num+=1
    #print(num,end=" ")
    if num==5:
        #pass
        #break
        continue
    print("The number is :", num)
print("We are out of the loop")

# %%
# While

# %%
num = 5
while num>0:
    print(num)
    #num=num+1
    num-=1
print("we're out of the loop")

# %%
num = 5
while True:
    print(num)
    #num=num+1
    num-=1
    if num<0:
        break
print("we're out of the loop")

# %%
num = 88
# Ask the user for a integer input.Guess the number till it is equal to variable num

# %%
l = [10,20,30]

# %%
l1 = l

# %%
l2 = l[:]

# %%
l2.append(100)

# %%
l3 = l1.copy()

# %%
l = []
for i in range(10):
    if i%2==0:
        l.append(i)

# %%
[i*i for i in range(10)]

# %%
[i for i in range(10) if i%2==0]

# %%
for i in l:
    print(i*i)

# %%
# Functions --> Reusable block of code--> logic

# %%
def sq(x):
    '''This function prints
    square of a given collection/iterable object'''
    for i in x:
        print(i*i)

# %%
sq(l)

# %%
sq((10,2,4,8))

# %%
def sq(x):
    #print(x*x)
    return x*x

# %%
y=sq(10)

# %%
type(y)

# %%
sq(l)

# %%
def fn1(x="hi"):
    print(x*2)

# %%
fn1("hi")

# %%
v1=sq(10)

# %%
type(v1)

# %%
fn1()

# %%
fn1(x='hello ')

# %%
def addition(x1,x2,x3=10):
    return sum([x1,x2,x3])

# %%
addition(10,20)

# %%
def args(*x):
    '''the * let's you pass n 
    number of arguments into a function
    '''
    #return sum([*x])
    return([x])

# %%
args(1,2,3,4,5,6,7,8.2)

# %%
def args(**x):
    '''the * let's you pass n 
    number of keyword arguments into a function
    '''
    for i,j in x.items():
        print(i,j)

# %%
args(blr=int(10.16780),mum=20,cbe=2,che=10,kol=5)

# %%
isinstance(100,int)

# %%
isinstance('a',int)

# %%
def greet(name:str,age:int):
         if not isinstance(name,str):
             raise TypeError("name must be a string")
         if not isinstance(age,int):
             raise TypeError("age must be an integer")

# %%
greet('john',100.567)

# %%
# Functional programming constructs --> pythonic
# map, filter, reduce, lambda, zip, generator, decorator, enumerate

# %%
# Big oh notation --> time complexity, space complexity

# %%
# write a function to find a number as prime or not

# %%
[i*i for i in l]

# %%
list(map(lambda i:i*i,l))

# %%
def even(x):
    if x%2==0:
        return x

# %%
even(5)

# %%
l = [1,2,3,4,5]

def sq(i):
    return i*i

# %%
list(map(sq,l))

# %%
tuple(map(even,l))

# %%
list(map(even,l))

# %%
list(filter(even,l))

# %%
d['eid']

# %%
list(map(sq,d['eid']))

# %%
lambda x:x*x

# %%
list(map(lambda x:x*x,l))

# %%
list(map(lambda x:x*x if x%2==0 else x,l))

# %%
reduce(lambda x,y:x if x<y else y,l)

# %%
l=[10,15,5,4,88]

# %%
reduce(lambda x,y:x if x+y else y,l)

# %%
# Write a function to find maximum of 5 numbers

# %%
max(10,22,35,45,5)

# %%
from functools import reduce

# %%
reduce(lambda)

# %%
def fn():
    for i in range(5):
        print(i*i)

# %%
fn()

# %%
def fn():
    for i in range(5):
        yield(i*i)

# %%
v = fn()

# %%
s = "hello class"

# %%
c = 0
for letter in s:
    print("At the index {} the letter is {} " .format(c,letter))
    c+=1

# %%
for index,letter in enumerate(s):
    print("At the index {} the letter is {} " .format(index,letter))

# %%
sal = [100,200,300,400]

# %%
emp_names = ['John','Sean','Monika','Peter']

# %%
l2=list(zip(sal,emp_names))

# %%
l2

# %%
for i,j in l2:
    print(i,j)

# %%
dict(zip(emp_names,sal))

# %%
for i in l2:
    print(i[0])

# %%
d=dict(zip(l,l1))

# %%
# Unzip
list(zip(*l2))

# %%
def new_decorator(actual_func):
    ''' This is a demo of a decorator function'''
    def wrapper_func():
        print("Statement before the execution of the function")
        actual_func()
        print("The statement after the execution of the function")
    return wrapper_func

# %%
@new_decorator
def new_func():
    print("Hello I am yet to be decorated")
new_func()

# %%
# Scope of a variable --. LEGB

# %%
x = 20

def example():
    global x
    print("The value of x now is :", x)
    x = 15
    print("The value of x is now changed to : ", x)

# %%
x

# %%
example()

# %%
x

# %%
num=int(input("please enter a number : "))
print("8 devided by {} is {}".format(num,8/num))
print("goodbye")

# %%
num=int(input("please enter a number : "))
if num==0:
    print('division by zero is not allowed')
else:
    print("8 devided by {} is {}".format(num,8/num))

# %% [raw]
# # Exception handling
# try
# except
# finally
# else
# assert
# eval
# raise exception
# Exception

# %%
try:
    num=int(input("please enter a number : "))
    print("8 devided by {} is {}".format(num,8/num))
except:
    print('Enter a valid number')

# %%
8/int(input("please enter a number : "))

# %%
try:
    print(8/int(input("please enter a number : ")))
except ValueError as ve:
    print(ve.args)
except ZeroDivisionError as ze:
    print(ze.args)
except Exception as e:
    print(e.args)
finally:
    print("I am executed regardless of other blocks")

# %%
try:
    fp = open("test1.txt")
    print("File opened")
    print(fp.read())
except:
    print("file not found")  
finally:
    #fp.close()
    print( "File closed" )

# %%
x = 5
y = eval("x+15")
print(y)

# %%
def greet(name:str,age:int):
         if not isinstance(name,str):
             raise TypeError("name must be a string")
         if not isinstance(age,int):
             raise TypeError("age must be an integer")

# %%
def getStringLenMax10():
    s = input()
    if len(s)>10:
        raise ValueError("Length exceeds 10", len(s))
    return s

# %%
getStringLenMax10()

# %%
def calculate_area(width,height):
    assert width>0, "width should be a positive number"
    assert height>0, "Height should be a positive number"
    return width*height

# %%
calculate_area(15,0)

# %%
try:
    5+10
except:
    print("put a valid number")
else:
    print("works fines")

# %%
# file handling

# %%
pwd

# %%
# %%writefile test.txt
# Hi welcome to the python course
# let us learn to work on files

# %%
f = open('test.txt')

# %%
f.read()

# %%
f.read()

# %%
f.seek(0)

# %%
f.read()

# %%
help(open)

# %% [raw]
# ========= ===============================================================
#     Character Meaning
#     --------- ---------------------------------------------------------------
#     'r'       open for reading (default)
#     'w'       open for writing, truncating the file first
#     'x'       create a new file and open it for writing
#     'a'       open for writing, appending to the end of the file if it exists
#     'b'       binary mode
#     't'       text mode (default)
#     '+'       open a disk file for updating (reading and writing)
#     ========= ===============================================================

# %%
f.close()

# %%
f = open('test.txt','w')

# %%
f.read()

# %%
f.write('hi this is my first line')

# %%
f.close()

# %%
f = open('test.txt','a+')

# %%
f.read()

# %%
f.seek(0)

# %%
f.read()

# %%
f.writelines('this is my second line')

# %%
f.writelines('and here is the third')

# %%
f.seek(0)

# %%
f.read()

# %%
f.readlines()

# %%
f.write(' \n and this time the 4th line')

# %%
f.close()

# %%
open('E:/LTI/stats_summary.txt','r+').readlines()

# %%
# With --> Better syntax, exception handling and no need to close the file

# %%
with open('test.txt') as file:
    data = file.read()

# %%
print(data)

# %%
with open('test.txt', 'w+') as file:
    data = file.write("Hello")
    #file.seek(0)
    #file.read()

# %%
# Serialization & Deserialization --> pickle

# %%
import pickle

# %%
d = {'id':[1,2,3],'sal':(10000,2000,3000),'City':['mum','cbe','che']}

# %%
ser = pickle.dumps(d)

# %%
ser

# %%
pickle.loads(ser)

# %%
import math

# %%
pwd

# %%
dir(math)

# %%
math.sqrt(100)

# %%
from math import sqrt, exp, log as lg

# %%
lg(100)

# %%
sqrt(1100)

# %%
#from math import *

# %%
from numpy.random import randn

# %%
l = [1,2,3,4]

# %%
l1 = [10,20,30,40]

# %%
l+l1

# %%
len(l)

# %%
# Numerical python --> n dimentional arrays

# %%
import numpy as np

# %%
np.array(l).shape

# %%
np.array(l)

# %%
np.array(l).reshape(2,2)

# %%
np.array(l).reshape(2,2)+np.array(l1).reshape(2,2)

# %%
np.array([10,69,45,78,45,23,76,56,33,16,72,18]).reshape(3,4)

# %%
np.array([10,69,45,78,45,23,76,56,33,16,72,18]).reshape(4,3)

# %%
arr = np.array([[10,50,80],[1,4,2],[3,8,5],[1,3,1]])

# %%
arr

# %%
arr.reshape(3,4)

# %%
# indexing

# %%
l[::]

# %%
arr[::,::]

# %%
arr[:,:2]

# %%
arr[1:,:]

# %%
arr[1:3,1]

# %%
arr[1:3,1:]

# %%
arr[:2,1:]

# %%
arr[1:3,[0,2]]

# %%
arr.T

# %%
arr.transpose()

# %%
arr.max()

# %%
arr

# %%
arr.argmax()

# %%
arr.flatten()

# %%
dir(arr)

# %%
np.choose()

# %%
choices = [[0, 1, 2, 3], [10, 11, 12, 13],[20, 21, 22, 23], [30, 31, 32, 33]]

# %%
np.choose([2, 3, 1, 0], choices)

# %%
np.ones(shape=(2,3))

# %%
np.zeros((2,3))

# %%
dir(np)

# %%
from numpy import random

# %%
random.rand(2,3)

# %%
random.randint(0,5,2)

# %%
random.randn(25)

# %%
#!pip install seaborn

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(random.randn(235))

# %%
sns.displot(random.randn(100))

# %%
# Pandas --> Series, Dataframes

# %%
# Series --> 1 dimentional
# Dataframe --> Multi dimentional

# %%
import pandas as pd

# %%
pd.Series(data=['a','b',20,30]).shape

# %%
pd.Series(data=['a','b',True, False])

# %%
pd.Series(data=[0,1,True,False], dtype='bool')

# %%
s=pd.Series(data=[12000,15000,10000,8000,7000,55000])

# %%
s[3]

# %%
pd.date_range('2026-02-09',periods=6)

# %%
pd.date_range('2026-02-09',periods=6, freq='3M')

# %%
pd.date_range('2026-02-09',periods=6, freq='7D')

# %%
dt=pd.date_range('2026-02-09',periods=6, freq='m')

# %%
s.index=dt

# %%
s['2026-06-30']

# %%
pd.Series(data=[12000,15000,10000,8000,7000,55000], index=dt)

# %%
s[4]

# %%
s.mean()

# %%
# Dataframes

# %%
pd.DataFrame(data=np.random.randn(4,3), columns=['Temp','power','energy'])

# %%
pd.DataFrame(data=np.array([[1,'mum'],[2,'cbe'],[3,'blr'],[4,'che']]), columns=['ID','CITY'])

# %%
pd.DataFrame(arr)

# %%
df=pd.DataFrame({'Day':['Mon','Tue','Wed','Fri','Sun'],'Temp':[32,17,24,22,15],
              'Cloudy':['Yes','No','No','Yes','No']})

# %%
df

# %%
# square bracket --> access columns by names/labels, then rows(slicing) by index

# %%
df['Day'][1:]

# %%
# df[1:]

# %%
df[['Day','Cloudy']][:3]

# %%
df[2:]['Day']

# %%
df[1:2]

# %%
#loc --> Access both rows and columns by labels

# %%
dt=dt.delete(5)

# %%
df.index=dt

# %%
df[['Day','Cloudy']][3:4]

# %%
df.loc['2026-05-31'][['Day','Cloudy']]

# %%
df.iloc[:3,[0,2]]

# %%
df['Rained'] = ['Yes','no','yes','no','Yes']

# %%
df['Humidity'] = ['high','no','high','normal','normal']

# %%
df.insert(2,'Humidity',['high','no','high','normal','normal'], allow_duplicates=True)

# %%
del(df['Humidity'])

# %%
df[(df['Temp']<25) | (df['Rained'].str.lower()=='yes')]

# %%
df[(df['Temp']<25) & (df['Rained'].str.capitalize()=='Yes')]

# %%
df.reset_index(drop=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.size

# %%
df['Temp'].sum()

# %%
df.rename_axis

# %%
df1 = pd.DataFrame({"num_legs": [4, 4, 2],"num_arms": [0, 0, 2]},["dog", "cat", "monkey"])

# %%
df1.index = pd.MultiIndex.from_product([['mammal'],['dog', 'cat', 'monkey']],names=['type', 'name'])

# %%
df1.index

# %%
pd.MultiIndex.from_tuples

# %%
df1.loc['mammal','cat']
